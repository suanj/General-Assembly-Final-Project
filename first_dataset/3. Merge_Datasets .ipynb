# %% [markdown]
# ### Music Playlist Youtube Channel

# %%
import pandas as pd

# %%
# import extracted datasets 
channel_1 = pd.read_csv('./Youtube_scraped_data/#yelocdirae 옐럭.csv')
channel_2 = pd.read_csv('./Youtube_scraped_data/;luv_muzik.csv')
channel_3 = pd.read_csv('./Youtube_scraped_data/alex_aero.csv')
channel_4 = pd.read_csv('./Youtube_scraped_data/essential;.csv')
channel_5 = pd.read_csv('./Youtube_scraped_data/homemade_cappuccino.csv')
channel_6 = pd.read_csv('./Youtube_scraped_data/honi_milk.csv')
channel_7 = pd.read_csv('./Youtube_scraped_data/ivoryyy.csv')
channel_8 = pd.read_csv('./Youtube_scraped_data/ivy_station_records.csv')
channel_9 = pd.read_csv('./Youtube_scraped_data/le_fyse.csv')
channel_10 = pd.read_csv('./Youtube_scraped_data/thanks_for_coming.csv')
channel_11 = pd.read_csv('./Youtube_scraped_data/uslessclout.csv')
channel_12 = pd.read_csv('./Youtube_scraped_data/yellow_mixtape.csv')
channel_13 = pd.read_csv('./Youtube_scraped_data/한번 들어봐.csv')

# %%
channel_1.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time                       title  \
# 0           0  juhZlwS0ekw  2020-09-05T04:48:33Z  [playlist] 도입부부터 미쳐버린 팝송모음
#
#                  channel_Id   channel_title  \
# 0  UCIVGTOc8ZwAKtWc_awlzskg  #yeLocDirAe 옐럭
#
#                                                 tags  views_count  \
# 0  ['도입부부터지리는팝송', '나만알고싶은팝송추천', '도입부팝송추천', '매장에서틀...      1613898
#
#    likes_count  dislikes_count  favorites_count  comments_count  duration
# 0        47877             264                0            1103  PT49M42S

# %%
channel_2.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time                       title  \
# 0           0  wM8ZIt2yRNM  2019-02-23T22:01:19Z  그루비한 외국 알앤비 GROOVY R&B ♩♪♬
#
#                  channel_Id channel_title  \
# 0  UCSKKTCtO8NBwVahO9nn1Oag  ;D LUV MUZIK
#
#                                                 tags  views_count  \
# 0  ['알앤비', '소울', '외국노래', '외국알앤비', '매장음악', '그루비한',...      1125903
#
#    likes_count  dislikes_count  favorites_count  comments_count  duration
# 0        31479             234                0             372  PT50M44S

# %%
channel_3.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time                   title  \
# 0           0  gVugqIBkgbA  2018-10-15T16:30:56Z  Lost Tapes | Chill Mix
#
#                  channel_Id channel_title  \
# 0  UCTdn10ESvSLuJHShEV4S6qA     Alex Aero
#
#                                                 tags  views_count  \
# 0  ['Summer Chill Mix', 'Alex Aero', 'Alexaero mi...      6356006
#
#    likes_count  dislikes_count  favorites_count  comments_count  duration
# 0        92946            1764                0             809  PT40M15S

# %%
channel_4.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  DFH2NpzgQ2E  2020-11-12T04:00:10Z
#
#                                                title  \
# 0  [Playlist] 슬슬 연말 분위기를 내볼까요? | 퍼펙트 크리스마스 캐롤 플레이...
#
#                  channel_Id channel_title  \
# 0  UCSGC87iX0QhnIfUOI_B_Rdg    essential;
#
#                                                 tags  views_count  \
# 0  ['에센셜', 'essential', '팝송', '캐롤', '추천', '음악', '...      7804261
#
#    likes_count  dislikes_count  favorites_count  comments_count    duration
# 0        60202            1932                0          5556.0  PT2H56M44S

# %%
channel_5.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  tnI6UJlvB2k  2020-06-20T20:19:06Z
#
#                                         title                channel_Id  \
# 0  summer mornings on the beach 🍨 (chill mix)  UCWIjaWowE7eDncdBJCdIclQ
#
#          channel_title                                               tags  \
# 0  homemade cappuccino  ['summer 2016', 'summer mix', 'songs that brin...
#
#    views_count  likes_count  dislikes_count  favorites_count  comments_count  \
# 0     10945286        93721            1117                0             410
#
#   duration
# 0  PT7M58S

# %%
channel_6.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  Sxsqvv2q4IM  2020-11-13T16:23:10Z
#
#                                                title  \
# 0  songs to listen to when you're feeling like th...
#
#                  channel_Id channel_title  tags  views_count  likes_count  \
# 0  UCRSKYzCHRFXz-yQCcWqT80w     honi milk   NaN       629369        28745
#
#    dislikes_count  favorites_count  comments_count  duration
# 0             167                0             528  PT49M45S

# %%
channel_7.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  nTFOunpypvY  2021-01-05T18:30:09Z
#
#                                                title  \
# 0  “I cant talk right now i'm doing hot girl thin...
#
#                  channel_Id channel_title  tags  views_count  likes_count  \
# 0  UCnGmBXByMLfahKc8KalRjew       Ivoryyy   NaN      1784654       107518
#
#    dislikes_count  favorites_count  comments_count  duration
# 0             434                0          1301.0  PT33M29S

# %%
channel_8.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  Wld5taGa1ag  2020-08-11T18:00:05Z
#
#                                 title                channel_Id  \
# 0  If J. Cole made lofi hip hop radio  UCv7qaGzuEfLhKxAZf4eZONg
#
#          channel_title                                               tags  \
# 0  Ivy Station Records  ['J cole', 'J Cole', 'dreamville', 'lights ple...
#
#    views_count  likes_count  dislikes_count  favorites_count  comments_count  \
# 0       331167        20979             127                0             382
#
#   duration
# 0  PT18M6S

# %%
channel_9.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  O7RnNTXPvvo  2020-12-07T18:24:15Z
#
#                               title                channel_Id channel_title  \
# 0  Mac Miller 1 Hour of Chill Songs  UC5blzC64V7R1hwgXbXWQfZQ       Le Fyse
#
#                                                 tags  views_count  \
# 0  ['mac miller', '1 hour of chill songs', 'chill...       396953
#
#    likes_count  dislikes_count  favorites_count  comments_count duration
# 0         5663             107                0             165   PT1H7S

# %%
channel_10.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time                     title  \
# 0           0  vXENF8VSBss  2020-01-08T09:43:20Z  스르륵 잠이 들고 싶은데 (playlist)
#
#                  channel_Id       channel_title  \
# 0  UCUbNhCJCQH-94fKhqKyTN-g  thanks for coming.
#
#                                                 tags  views_count  \
# 0  ['때껄룩', '떼껄룩', '플레이리스트', 'playlist', '시플', '시럽...      1921841
#
#    likes_count  dislikes_count  favorites_count  comments_count   duration
# 0        45824             319                0          2708.0  PT1H4M23S

# %%
channel_11.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  MSCyADD8cuM  2020-11-13T16:23:24Z
#
#                                                title  \
# 0  a playlist that will make you feel like the ma...
#
#                  channel_Id channel_title  \
# 0  UC9j8EtEcx-ah8bkxd2OqbgQ  UselessClout
#
#                                                 tags  views_count  \
# 0  ['main character songs', 'main character playl...      3126695
#
#    likes_count  dislikes_count  favorites_count  comments_count  duration
# 0       131710             649                0            2600  PT45M15S

# %%
channel_12.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  7cR8rOx-f3A  2019-04-26T02:57:21Z
#
#                                                title  \
# 0  #Playlist II 샤워할때 들으면 수도세 폭발해서 엄마한테 등짝맞는 힙한 플레...
#
#                  channel_Id   channel_title                      tags  \
# 0  UC4Oqg2xJLbOkGnTpn68pErA  yellow mixtape  ['샤워할때', '팝송', '플레이리스트']
#
#    views_count  likes_count  dislikes_count  favorites_count  comments_count  \
# 0      4257928        61495            1493                0            3034
#
#    duration
# 0  PT35M20S

# %%
channel_13.head(1)
# Out:
#    Unnamed: 0     video_id          publish_time  \
# 0           0  mxJGDa7ThbE  2020-06-09T02:30:30Z
#
#                                    title                channel_Id  \
# 0  [Playlist] 귀르가즘 제대로 주는 갬성 팝송 노래 모음 #2  UCxLzfLcNEtXsOSE_ysUTnXQ
#
#   channel_title                                               tags  \
# 0        한번 들어봐  ['노래', '노래모음', '팝송', '팝송모음', '귀르가즘', '띵곡', '띵곡...
#
#    views_count  likes_count  dislikes_count  favorites_count  comments_count  \
# 0      4864124        53244             615                0            1820
#
#     duration
# 0  PT1H6M24S

# %%
#Merge datasets into one dataframe.
youtube = pd.concat([channel_1, channel_2, channel_3, channel_4, channel_5,
                    channel_6, channel_7, channel_8, channel_9, channel_10, channel_11,
                    channel_12, channel_13])
youtube.reset_index(inplace=True)
youtube.head()
# Out:
#    index  Unnamed: 0     video_id          publish_time  \
# 0      0           0  juhZlwS0ekw  2020-09-05T04:48:33Z
# 1      1           1  99CQFkXOZss  2020-09-27T02:00:03Z
# 2      2           2  pYDm6tqjIOA  2020-06-24T12:44:05Z
# 3      3           3  Wg1ayLoxNCU  2020-10-02T14:30:11Z
# 4      4           4  _WXvQz4sjBU  2020-09-23T07:00:07Z
#
#                                        title                channel_Id  \
# 0                 [playlist] 도입부부터 미쳐버린 팝송모음  UCIVGTOc8ZwAKtWc_awlzskg
# 1   [playlist] 너무 과하지 않는 일렉에 그렇지 못한 텐션 EDM모음  UCIVGTOc8ZwAKtWc_awlzskg
# 2                  [playlist] 도입부부터 지리는 팝송모음  UCIVGTOc8ZwAKtWc_awlzskg
# 3  [playlist] 여러분이 좋아하실만한 듣기 편한 팝송을 가져왔어요 #2  UCIVGTOc8ZwAKtWc_awlzskg
# 4                  [playlist] 도입부부터 흥타는 팝송모음  UCIVGTOc8ZwAKtWc_awlzskg
#
#     channel_title                                               tags  \
# 0  #yeLocDirAe 옐럭  ['도입부부터지리는팝송', '나만알고싶은팝송추천', '도입부팝송추천', '매장에서틀...
# ...

# %%
#drop unnecessary columns.
youtube = youtube.drop(['index', 'Unnamed: 0'], axis = 1)

# %%
#check shape of each dataset to make sure if all of them merged properly.
print(channel_1.shape)
print(channel_2.shape)
print(channel_3.shape)
print(channel_4.shape)
print(channel_5.shape)
print(channel_6.shape)
print(channel_7.shape)
print(channel_8.shape)
print(channel_9.shape)
print(channel_10.shape)
print(channel_11.shape)
print(channel_12.shape)
print(channel_13.shape)
print(youtube.shape)
# Out:
# (100, 13)
# (19, 13)
# (39, 13)
# (182, 13)
# (15, 13)
# (5, 13)
# (68, 13)
# (63, 13)
# (31, 13)
# (96, 13)
# (12, 13)
# (87, 13)
# (95, 13)
# (812, 12)

# %%
#save as csv file. 
youtube.to_csv('youtube_final_data_for_real.csv')
